# %% [markdown]
# <a href="https://colab.research.google.com/github/Varma03062003/Netflix-Content-Analytics/blob/main/Netflix_Content_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Netflix")
# Out:
# Hello Netflix

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_PATH = "/content/drive/MyDrive/Data_Analytics_Projects/Netflix_Content_Analytics"

# %%
RAW_PATH = PROJECT_PATH + "/data/raw"

# %%
import os

# %%
PROJECT_PATH = "/content/drive/MyDrive/Data_Analytics_Projects/Netflix_Content_Analytics"

# %%
RAW_PATH = PROJECT_PATH + "/data/raw"

# %%
import os

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Opal',
#  'Ravi_Varma_Resume (1).pdf',
#  'Ravi_Varma_Resume.pdf',
#  'VANGALA RAVI VARMA-1.pdf',
#  'IMG-20260218-WA0004.jpg',
#  '3 Pattern DSA tcs nqt-1.pdf',
#  'TCS nqt-50 coding question -1.pdf',
#  'Tcs Nqt2026--  300- pyq-1.pdf',
#  'EXCEL',
#  'Data_analytics_Project']

# %%
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Opal',
#  'Ravi_Varma_Resume (1).pdf',
#  'Ravi_Varma_Resume.pdf',
#  'VANGALA RAVI VARMA-1.pdf',
#  'IMG-20260218-WA0004.jpg',
#  '3 Pattern DSA tcs nqt-1.pdf',
#  'TCS nqt-50 coding question -1.pdf',
#  'Tcs Nqt2026--  300- pyq-1.pdf',
#  'EXCEL',
#  'Data_analytics_Project']

# %%
os.listdir('/content/drive/MyDrive/Data_analytics_Project')
# Out:
# ['Netflix_Content_Analytics']

# %%
os.listdir('/content/drive/MyDrive/Data_analytics_Project/Netflix_Content_Analytics')
# Out:
# ['data']

# %%
os.listdir('/content/drive/MyDrive/Data_analytics_Project/Netflix_Content_Analytics/data')
# Out:
# ['raw']

# %%
os.listdir('/content/drive/MyDrive/Data_analytics_Project/Netflix_Content_Analytics/data/raw')
# Out:
# ['netflix_titles.csv']

# %%
PROJECT_PATH = "/content/drive/MyDrive/Data_analytics_Project/Netflix_Content_Analytics"
